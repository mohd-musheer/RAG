# %% [markdown]
# ### Load Single File

# %%
from langchain_community.document_loaders import TextLoader

loader=TextLoader(
    "data/CSV/text.txt"
)
data=loader.load()
print(data)
# Out:
# [Document(metadata={'source': 'data/CSV/text.txt'}, page_content='This error is **not from Groq itself**. It\'s from one of your MCP tools returning data in a format that LangChain/Groq cannot serialize into a tool message.\n\nThe key part is:\n\n```text\ngroq.BadRequestError:\n\'messages.4.content\'\nfor role:tool\ncontent must be a string\n```\n\nThat means one of your MCP tools returned:\n\n```python\nreturn {\n    "main_topics": [...],\n    "important_points": [...]\n}\n```\n\nor\n\n```python\nreturn list(...)\n```\n\ninstead of a string.\n\n---\n\n### Why it worked before\n\nYour Gmail MCP returned:\n\n```python\nreturn "\\n".join(emails)\n```\n\nwhich is a string.\n\nYour Drive MCP probably returned:\n\n```python\nreturn str(files)\n```\n\nwhich is also a string.\n\nGroq was happy.\n\n---\n\n### What changed\n\nYour Analytics MCP returns:\n\n```python\nreturn result.model_dump()\n```\n\nwhich returns a Python dictionary:\n\n```python\n{\n  "main_topics": [...],\n  "important_points": [...],\n  "action_items": [...],\n  "short_summary": "..."\n}\n```\n\nMany MCP adapters and Groq tool-calling paths expect:\n\n```python\ntool_result.content == str\n```\n\nnot a dict.\n\n---\n\n### Quick fix\n\nChange:\n\n```python\nreturn result.model_dump()\n```\n\nto:\n\n```python\nimport json\n\nreturn json.dumps(\n    result.model_dump(),\n    indent=2\n)\n```\n\nor\n\n```python\nreturn result.model_dump_json()\n```\n\n---\n\n### Better MCP version\n\n```python\n@mcp.tool()\ndef summarize_data(data: str):\n\n    result = structured_model.invoke(\n        f"""\n        Analyze:\n\n        {data}\n        """\n    )\n\n    return result.model_dump_json(indent=2)\n```\n\nNow the tool returns:\n\n```json\n{\n  "main_topics": [\n    "AI Jobs"\n  ],\n  "important_points": [\n    "Forage AI Internship"\n  ],\n  "action_items": [\n    "Apply"\n  ],\n  "short_summary": "Recent emails focus on AI jobs."\n}\n```\n\nas a **string**, which Groq accepts.\n\n---\n\n### Another issue\n\nYour user query:\n\n```text\nis there any email without unwanted label in my previous 15 emails?\n```\n\nis vague.\n\nThe agent has to infer what:\n\n```text\nunwanted label\n```\n\nmeans.\n\nDoes it mean:\n\n* Promotions?\n* Spam?\n* Job alerts?\n* Marketing emails?\n\nThe model may call multiple tools trying to figure it out.\n\nTry:\n\n```text\nAmong my last 15 emails, which ones are not job alerts, promotions, or newsletters?\n```\n\nMuch clearer.\n\n---\n\n### Debug tip\n\nBefore returning from Analytics MCP:\n\n```python\nprint(type(result.model_dump()))\n```\n\nI expect you\'ll see:\n\n```python\n<class \'dict\'>\n```\n\nwhich confirms the source of the error.\n\nSo the most likely fix is:\n\n```python\nreturn result.model_dump_json()\n```\n\nin `summarize_data.py`.\n')]

# %%
from langchain_community.document_loaders import PyMuPDFLoader

loader = PyMuPDFLoader(
    "data/PDF/first.pdf",
)

doc= loader.load()

print(doc)
# Out:
# [Document(metadata={'producer': 'WeasyPrint 68.1', 'creator': '', 'creationdate': '', 'source': 'data/PDF/first.pdf', 'file_path': 'data/PDF/first.pdf', 'total_pages': 7, 'format': 'PDF 1.7', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 0}, page_content='Price Per Token Guide to Using Fewer\nTokens\nMost developers use 2-5x more tokens than they need to. Here\'s how to fix that.\nThis guide covers eight practical ways to cut your token usage. Each one is independent\n— you can start with whichever applies to you — but they compound when used together.\nTip 1: Trim Your System Prompt\nYour system prompt gets sent with every single API call. There\'s no getting around that if\nyou\'re using an LLM as an assistant because each call is stateless- all the context needs\nto be included in every input. It is worth spending time on a frequently used system prompt\nfor this reason\nMost system prompts are far longer than they need to be. Common sources of bloat:\n"You are a helpful assistant that..." — The model already knows this. Cut it.\nRedundant formatting instructions — Telling the model three different ways to use\nbullet points doesn\'t help more than telling it once.\nPoliteness and motivation — "Please always try your best to provide accurate..." is\nfiller. LLMs don\'t try harder because you said please.\nReference material — If you\'re pasting documentation into the system prompt, move it\nto retrieval (RAG) or tool calls instead. It doesn\'t belong in every request.\nThe rule of thumb: Remove a line from your system prompt. If the model\'s behavior\ndoesn\'t change, leave it out.\nExample:\nBefore (roughly 800 tokens):\nYou are a helpful, knowledgeable AI assistant specializing in customer support\nfor our e-commerce platform. You should always be polite, professional, and\nthorough in your responses. When a customer asks about an order, you should\nlook up their order details and provide a comprehensive summary including the\norder date, items ordered, shipping status, estimated delivery date, and any\nrelevant tracking information. You should always ask if there\'s anything else\nyou can help with at the end of your response. If you don\'t know the answer,\n• \n• \n• \n•'), Document(metadata={'producer': 'WeasyPrint 68.1', 'creator': '', 'creationdate': '', 'source': 'data/PDF/first.pdf', 'file_path': 'data/PDF/first.pdf', 'total_pages': 7, 'format': 'PDF 1.7', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 1}, page_content='say so honestly rather than making something up. Format your responses clearly\nwith bullet points where appropriate...\nAfter (roughly 200 tokens):\nCustomer support agent for [Company]. Look up order details when asked.\nBe concise. If unsure, say so. Use the order_lookup tool for order queries.\nSame behavior. 600 fewer tokens per call. At 200 calls/day, that\'s 120,000 tokens saved\ndaily — purely from deleting words the model didn\'t need. Details about looking up order\ndates, items ordered, etc can be included in tool definitions and picked up into context only\nwhen necessary.\nTip 2: Control Your Output Length\nIf you don\'t tell the model how long to respond, it will use as many tokens as it wants. This\nmatters because output tokens are the expensive ones — typically 3-5x the cost of input\ntokens.\nA few ways to control this:\nSet max_tokens  explicitly. Most people leave this at the default, which is often the\nmodel\'s maximum context window. If you only need a one-paragraph answer, don\'t leave\nroom for an essay.\nBe specific in your instructions: - "Respond in 2-3 sentences" works better than "be\nbrief" - "Keep your answer under 100 words" gives a hard target - "Return only the\ncategory name, nothing else" eliminates all filler\nAsk for bullets instead of prose. The same information in bullet point format uses fewe ...

# %% [markdown]
# ### Load Multiple File

# %%
from langchain_community.document_loaders import DirectoryLoader
from langchain_community.document_loaders import TextLoader

loader = DirectoryLoader(
    "data/CSV",
    glob="*.txt",
    loader_cls=TextLoader,
    loader_kwargs={"encoding": "utf-8"}
)

docs = loader.load()

print(f"Loaded {len(docs)} documents")
for i in docs:
    print(i)
# Out:
# Loaded 3 documents
# page_content='This error is **not from Groq itself**. It's from one of your MCP tools returning data in a format that LangChain/Groq cannot serialize into a tool message.
#
# The key part is:
#
# ```text
# groq.BadRequestError:
# 'messages.4.content'
# for role:tool
# content must be a string
# ```
#
# That means one of your MCP tools returned:
#
# ```python
# return {
#     "main_topics": [...],
#     "important_points": [...]
# }
# ```
#
# or
#
# ```python
# return list(...)
# ```
#
# instead of a string.
#
# ---
#
# ### Why it worked before
#
# Your Gmail MCP returned:
#
# ```python
# return "\n".join(emails)
# ```
#
# which is a string.
#
# Your Drive MCP probably returned:
#
# ```python
# return str(files)
# ```
#
# which is also a string.
#
# Groq was happy.
#
# ---
#
# ### What changed
#
# Your Analytics MCP returns:
#
# ```python
# return result.model_dump()
# ```
#
# which returns a Python dictionary:
#
# ```python
# {
#   "main_topics": [...],
#   "important_points": [...],
#   "action_items": [...],
#   "short_summary": "..."
# }
# ```
#
# Many MCP adapters and Groq tool-calling paths expect:
#
# ```python
# tool_result.content == str
# ```
#
# not a dict.
#
# ---
#
# ### Quick fix
#
# Change:
#
# ```python
# return result.model_dump()
# ```
#
# to:
#
# ```python
# import json
#
# return json.dumps(
#     result.model_dump(),
#     indent=2
# )
# ```
#
# or
#
# ```python
# return result.model_dump_json()
# ```
#
# ---
#
# ### Better MCP version
#
# ```python
# @mcp.tool()
# def summarize_data(data: str):
#
#     result = structured_model.invoke(
#         f"""
#         Analyze:
#
#         {data}
#         """
#     )
#
#     return result.model_dump_json(indent=2)
# ```
#
# Now the tool returns:
#
# ```json
# {
#   "main_topics": [
#     "AI Jobs"
#   ],
#   "important_points": [
#     "Forage AI Internship"
#   ],
#   "action_items": [
#     "Apply"
#   ],
#   "short_summary": "Recent emails focus on AI jobs."
# }
# ```
#
# as a **string**, which Groq accepts.
#
# ---
#
# ### Another issue
#
# Your user query:
#
# ```text
# is there any email without unwanted label in my previous 15 emails?
# ```
#
# is vague.
#
# The agent has to infer what:
#
# ```text
# unwanted label
# ```
#
# means.
#
# Does it mean:
#
# * Promotions?
# * Spam?
# * Job alerts?
# * Marketing emails?
#
# The model may call multiple tools trying to figure it out.
#
# Try:
#
# ```text
# Among my last 15 emails, which ones are not job alerts, promotions, or newsletters?
# ```
#
# Much clearer.
#
# ---
#
# ### Debug tip
#
# Before returning from Analytics MCP:
#
# ```python
# print(type(result.model_dump()))
# ```
#
# I expect you'll see:
#
# ```python
# <class 'dict'>
# ```
#
# which confirms the source of the error.
#
# So the most likely fix is:
#
# ```python
# return result.model_dump_json()
# ```
#
# in `summarize_data.py`.
# ' metadata={'source': 'data\\CSV\\text.txt'}
# page_content='Yes, this is **significantly better** than your first version.
#
# ### What improved
#
# Before:
#
# * Only snippets were returned.
# * No sender names.
# * No subjects.
# * The LLM had to guess a lot.
#
# Now:
#
# * Sender is included.
# * Subject is included.
# * Date is included.
# * Snippets are included.
# * The agent can reason from structured email metadata.
#
# That is why it produced a much more useful summary.
#
# ---
#
# ### However, there is still a weakness
#
# Your Gmail tool currently returns:
#
# ```python
# {
#     "message_id": ...,
#     "subject": ...,
#     "from": ...,
#     "date": ...,
#     "snippet": ...
# }
# ```
#
# A Gmail snippet is only a small preview.
#
# For example:
#
# ```text
# Apply to jobs at Wipro, Infosys...
# ```
#
# The actual email may contain:
#
# * Salary
# * Location
# * Skills
# * Deadline
# * Application link
#
# but the agent never sees that.
#
# ---
#
# ### Next improvement
#
# Create another MCP tool:
#
# ```python
# @mcp.tool()
# def get_email_content(message_id: str):
# ```
#
# that returns:
#
# ```python
# {
#     "subject": subject,
#     "from": sender,
#     "date": date,
#     "body": body
# }
# ```
#
# Then the agent workflow becomes:
#
# ```text
# User
#  ↓
# get_recent_emails()
#  ↓
# Agent sees email list
#  ↓
# If user wants details
#  ↓
# get_email_content(message_id)
#  ↓
# Summarize
# ```
#
# This is how real email assistants work.
#
# ---
#
# ### Another issue
#
# Your current answer says:
#
# ```text
# Google warns of possible unauthorized access.
# ```
#
# The model inferred that from the subject.
#
# But it doesn't actually know whether it was:
#
# * your MCP app
# * OAuth login
# * suspicious login
# * new device login
#
# Because it only saw a snippet.
#
# So that conclusion is somewhat speculative.
#
# A better agent would call:
#
# ```python
# get_email_content(message_id)
# ```
#
# first, then summarize.
#
# ---
#
# ### For a GitHub project
#
# Current project quality:
#
# | Component            | Rating |
# | -------------------- | ------ |
# | Gmail MCP            | 8/10   |
# | Drive MCP            | 6/10   |
# | Analytics MCP        | 7/10   |
# | Agent orchestration  | 7/10   |
# | Production readiness | 4/10   |
#
# The next feature that would impress recruiters most is:
#
# ```text
# KnowledgeVault AI
#
# User:
# "Summarize my latest emails"
#
# Agent:
# 1. Gets email list
# 2. Selects important emails
# 3. Reads full email bodies
# 4. Creates structured summary
# 5. Stores memory of important items
# ```
#
# That moves it from a simple MCP demo to a genuine personal knowledge assistant.
#
# One more thing I noticed in your code dump: your Gmail and Drive auth helpers are duplicated almost line-for-line. Keep a single shared auth helper in `common/` and import it from both tools. That reduces maintenance and avoids bugs when you change scopes later.
# ' metadata={'source': 'data\\CSV\\text2.txt'}
# page_content='# 🚀 KnowledgeVault AI
#
# > AI-powered personal knowledge assistant built using **LangGraph**, **LangChain**, **MCP (Model Context Protocol)**, **Google Gmail API**, **Google Drive API**, and **Groq LLMs**.
#
# ---
#
# ## 📌 Overview
#
# KnowledgeVault AI is a multi-MCP agent that can connect to:
#
# * 📧 Gmail
# * 📁 Google Drive
# * 🧠 Analytics/Summarization Engine
#
# The agent can retrieve information from multiple sources and generate intelligent summaries using LLMs.
#
# ---
#
# ## ✨ Features
#
# ### Gmail MCP
#
# * Fetch recent emails
# * Search emails
# * Extract sender, subject, date, and snippets
# * Summarize inbox activity
#
# ### Google Drive MCP
#
# * List recent files
# * Search files by name
# * Retrieve file metadata
# * Analyze Drive activity
#
# ### Analytics MCP
#
# * Structured summarization
# * Main topics extraction
# * Important points extraction
# * Action item generation
# * Short summary generation
#
# ### Agent
#
# * Multi-server MCP integration
# * Tool calling with LangGraph
# * Autonomous reasoning
# * Cross-tool analysis
#
# ---
#
# # 🏗️ Architecture
#
# ```text
# User
#  │
#  ▼
# LangGraph Agent
#  │
#  ├── Gmail MCP
#  │      ├── get_recent_emails
#  │      └── search_emails
#  │
#  ├── Google Drive MCP
#  │      ├── list_drive_files
#  │      └── search_drive_files
#  │
#  └── Analytics MCP
#         └── summarize_data
# ```
#
# ---
#
# # 📂 Project Structure
#
# ```text
# KnowledgeVault-AI
# │
# ├── Agent
# │   └── client.py
# │
# ├── GmailMCPTools
# │   ├── emails.py
# │   └── google_auth_helper.py
# │
# ├── GoogleDriveMCPTools
# │   ├── google_drive.py
# │   └── google_auth_helper.py
# │
# ├── AnalyticsMCPTools
# │   └── summarize_data.py
# │
# ├── .env
# ├── credentials.json
# ├── token.json
# ├── requirements.txt
# ├── README.md
# └── pyproject.toml
# ```
#
# ---
#
# # ⚙️ Installation
#
# ## 1️⃣ Clone Repository
#
# ```bash
# git clone https://github.com/yourusername/KnowledgeVault-AI.git
#
# cd KnowledgeVault-AI
# ```
#
# ## 2️⃣ Create Virtual Environment
#
# ```bash
# python -m venv .venv
# ```
#
# ### Windows
#
# ```bash
# .venv\Scripts\activate
# ```
#
# ### Linux / Mac
#
# ```bash
# source .venv/bin/activate
# ```
#
# ## 3️⃣ Install Dependencies
#
# ```bash
# pip install -r requirements.txt
# ```
#
# ---
#
# # 🔑 Environment Variables
#
# Create a `.env` file:
#
# ```env
# GROQ_API_KEY=your_groq_api_key
# ```
#
# ---
#
# # ☁️ Google OAuth Setup
#
# ## Step 1 — Create Google Cloud Project
#
# Visit:
#
# ```text
# https://console.cloud.google.com
# ```
#
# Create a new project.
#
# ---
#
# ## Step 2 — Enable APIs
#
# Enable:
#
# * Gmail API
# * Google Drive API
#
# Path:
#
# ```text
# APIs & Services → Library
# ```
#
# ---
#
# ## Step 3 — Configure OAuth Consent Screen
#
# Navigate:
#
# ```text
# APIs & Services
# → OAuth Consent Screen
# ```
#
# Choose:
#
# ```text
# External
# ```
#
# Fill:
#
# * App Name
# * Support Email
# * Developer Email
#
# ---
#
# ## Step 4 — Add Scopes
#
# Add:
#
# ```text
# https://www.googleapis.com/auth/gmail.readonly
# ```
#
# ```text
# https://www.googleapis.com/auth/drive.readonly
# ```
#
# ---
#
# ## Step 5 — Add Test User
#
# Navigate:
#
# ```text
# OAuth Consent Screen
# → Test Users
# ```
#
# Add your Gmail account.
#
# ---
#
# ## Step 6 — Create OAuth Credentials
#
# Navigate:
#
# ```text
# Credentials
# → Create Credentials
# → OAuth Client ID
# ```
#
# Choose:
#
# ```text
# Desktop Application
# ```
#
# Download:
#
# ```text
# credentials.json
# ```
#
# Place it in the project root:
#
# ```text
# KnowledgeVault-AI/
# ```
#
# ---
#
# # 🔐 First Authentication
#
# Run:
#
# ```bash
# python -m GmailMCPTools.emails
# ```
#
# Google login page opens.
#
# Approve permissions.
#
# After successful authentication:
#
# ```text
# token.json
# ```
#
# will be generated automatically.
#
# ---
#
# # 🚨 Security Notes
#
# Never upload these files:
#
# ```text
# .env
# credentials.json
# token.json
# ```
#
# Add them to `.gitignore`.
#
# Example:
#
# ```gitignore
# .env
# credentials.json
# token.json
#
# __pycache__/
# *.pyc
# ```
#
# ---
#
# # ▶️ Running MCP Servers
#
# ## Gmail MCP
#
# ```bash
# python -m GmailMCPTools.emails
# ```
#
# Available tools:
#
# ```text
# get_recent_emails
# search_emails
# ```
#
# ---
#
# ## Google Drive MCP
#
# ```bash
# python -m GoogleDriveMCPTools.google_drive
# ```
#
# Available tools:
#
# ```text
# list_drive_files
# search_drive_files
# ```
#
# ---
#
# ## Analytics MCP
#
# ```bash
# python -m AnalyticsMCPTools.summarize_data
# ```
#
# Available tools:
#
# ```text
# summarize_data
# ```
#
# ---
#
# # 🤖 Running The Agent
#
# ```bash
# python -m Agent.client
# ```
#
# Example prompts:
#
# ```text
# Summarize my latest 5 emails
# ```
#
# ```text
# Show my recent Google Drive files
# ```
#
# ```text
# Summarize recent emails and Drive uploads
# ```
#
# ```text
# Find AI-related emails and summarize them
# ```
#
# ---
#
# # 📊 Example Output
#
# ```text
# Summary of Recent Emails
#
# - 4 job alerts
# - 1 Google security notification
#
# Action Items:
# 1. Review Google security alert
# 2. Apply to relevant AI/ML roles
# 3. Archive irrelevant newsletters
# ```
#
# ---
#
# # ⚠️ Current Limitations
#
# * Reads email metadata only
# * Does not fetch full email body
# * Reads Drive metadata only
# * Does not read actual file contents
# * Single-user OAuth flow
# * Local token storage
#
# ---
#
# # 🛣️ Roadmap
#
# ## Gmail MCP
#
# * [ ] Read full email body
# * [ ] Email classification
# * [ ] Email reply generation
#
# ## Drive MCP
#
# * [ ] Read file content
# * [ ] PDF parsing
# * [ ] Resume analysis
#
# ## Agent
#
# * [ ] Cross-source search
# * [ ] Memory support
# * [ ] FastAPI deployment
# * [ ] Docker deployment
# * [ ] Multi-user OAuth support
#
# ---
#
# # 📚 What I Learned
#
# This project helped me learn:
#
# * MCP Architecture
# * LangGraph
# * LangChain Agents
# * Tool Calling
# * Google OAuth
# * Gmail API
# * Google Drive API
# * Structured Outputs
# * Agentic AI Systems
#
# ---
#
# # 👨‍💻 Author
#
# **Musheer**
#
# KnowledgeVault AI – A personal knowledge assistant powered by MCP, LangGraph, Gmail, Google Drive, and Groq LLMs.
# ' metadata={'source': 'data\\CSV\\text3.txt'}

# %%
from langchain_community.document_loaders import DirectoryLoader
from langchain_community.document_loaders import PyMuPDFLoader

loader = DirectoryLoader(
    "data/PDF",
    glob="*.pdf",
    loader_cls=PyMuPDFLoader
)

docs = loader.load()

print(f"Loaded {len(docs)} pages")
for i in docs:
    print(i)
# Out:
# Loaded 9 pages
# page_content='Price Per Token Guide to Using Fewer
# Tokens
# Most developers use 2-5x more tokens than they need to. Here's how to fix that.
# This guide covers eight practical ways to cut your token usage. Each one is independent
# — you can start with whichever applies to you — but they compound when used together.
# Tip 1: Trim Your System Prompt
# Your system prompt gets sent with every single API call. There's no getting around that if
# you're using an LLM as an assistant because each call is stateless- all the context needs
# to be included in every input. It is worth spending time on a frequently used system prompt
# for this reason
# Most system prompts are far longer than they need to be. Common sources of bloat:
# "You are a helpful assistant that..." — The model already knows this. Cut it.
# Redundant formatting instructions — Telling the model three different ways to use
# bullet points doesn't help more than telling it once.
# Politeness and motivation — "Please always try your best to provide accurate..." is
# filler. LLMs don't try harder because you said please.
# Reference material — If you're pasting documentation into the system prompt, move it
# to retrieval (RAG) or tool calls instead. It doesn't belong in every request.
# The rule of thumb: Remove a line from your system prompt. If the model's behavior
# doesn't change, leave it out.
# Example:
# Before (roughly 800 tokens):
# You are a helpful, knowledgeable AI assistant specializing in customer support
# for our e-commerce platform. You should always be polite, professional, and
# thorough in your responses. When a customer asks about an order, you should
# look up their order details and provide a comprehensive summary including the
# order date, items ordered, shipping status, estimated delivery date, and any
# relevant tracking information. You should always ask if there's anything else
# you can help with at the end of your response. If you don't know the answer,
# •
# •
# •
# •' metadata={'producer': 'WeasyPrint 68.1', 'creator': '', 'creationdate': '', 'source': 'data\\PDF\\Price-Per-Token-Guide-To-Using-Fewer-Tokens.pdf', 'file_path': 'data\\PDF\\Price-Per-Token-Guide-To-Using-Fewer-Tokens.pdf', 'total_pages': 7, 'format': 'PDF 1.7', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 0}
# page_content='say so honestly rather than making something up. Format your responses clearly
# with bullet points where appropriate...
# After (roughly 200 tokens):
# Customer support agent for [Company]. Look up order details when asked.
# Be concise. If unsure, say so. Use the order_lookup tool for order queries.
# Same behavior. 600 fewer tokens per call. At 200 calls/day, that's 120,000 tokens saved
# daily — purely from deleting words the model didn't need. Details about looking up order
# dates, items ordered, etc can be included in tool definitions and picked up into context only
# when necessary.
# Tip 2: Control Your Output Length
# If you don't tell the model how long to respond, it will use as many tokens as it wants. This
# matters because output tokens are the expensive ones — typically 3-5x the cost of input
# tokens.
# A few ways to control this:
# Set max_tokens  explicitly. Most people leave this at the default, which is often the
# model's maximum context window. If you only need a one-paragraph answer, don't leave
# room for an essay.
# Be specific in your instructions: - "Respond in 2-3 sentences" works better than "be
# brief" - "Keep your answer under 100 words" gives a hard target - "Return only the
# category name, nothing else" eliminates all filler
# Ask for bullets instead of prose. The same information in bullet point format uses fewer
# tokens than full paragraphs. If you're going to extract the key points anyway, have the
# model do it upfront.
# For classification and routing tasks, constrain the output to a single word or a short
# JSON value. There's no reason a sentiment classifier should return "The sentiment of this
# text is positive because the author expresses satisfaction with..." when it could return
# "positive" .
# The math: If a typical response is 2,000 tokens and you can bring it down to 500, you're
# saving 75% on the most expensive part of every call. Check what output tokens cost for
# your model at pricepertoken.com — the difference between controlled and uncontrolled
# output adds up fast.' metadata={'producer': 'WeasyPrint 68.1', 'creator': '', 'creationdate': '', 'source': 'data\\PDF\\Price-Per-Token-Guide-To-Using-Fewer-Tokens.pdf', 'file_path': 'data\\PDF\\Price-Per-Token-Guide-To-Using-Fewer-Tokens.pdf', 'total_pages': 7, 'format': 'PDF 1.7', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 1}
# page_content='Tip 3: Use Structured Outputs
# When you need data back from a model — not conversation, not creative writing, just data
# — structured outputs are the most token-efficient way to get it.
# JSON mode and structured output schemas (available in OpenAI and Anthropic APIs)
# constrain the model's response to match a predefined format. That means:
# No "Sure! Here's what I found:" preamble
# No trailing "Let me know if you need anything else!"
# No inconsistent formatting between calls
# Just the fields you asked for, in the shape you defined
# Structured responses are typically 30-60% shorter than free-form text containing the same
# information. And they're easier to parse — no regex, no "sometimes it includes a header
# and sometimes it doesn't."
# When to use structured outputs: - Data extraction (pull name, date, amount from text) -
# Classification (return a category label, not an explanation of why) - Multi-step pipelines
# (pass clean data between steps) - Any time you're going to parse the response
# programmatically
# Pydantic AI is worth looking at if you're working in Python. It lets you define your output
# schema as a Pydantic model, and the LLM is forced to return data matching that schema.
# No parsing code, no surprises, no wasted tokens on filler text. It works across multiple
# providers including OpenAI and Anthropic.
# I personally strictly Pydantic AI for almost all use cases (I am not affiliated). It allows you to
# define each part of an output which in turn gives you predictable output formats at a
# controlled length.
# Tip 4: Cache What Doesn't Change
# Prompt caching gives you a 90% discount on tokens the API has already processed. If
# your prompts have a stable prefix — and most do — this is essentially free savings.
# How it works: The first time you send a prompt, you pay full price. On subsequent
# requests within the cache window (5 minutes for Anthropic, similar for OpenAI), any tokens
# that match the cached prefix cost 90% less.
# •
# •
# •
# •' metadata={'producer': 'WeasyPrint 68.1', 'creator': '', 'creationdate': '', 'source': 'data\\PDF\\Price-Per-Token-Guide-To-Using-Fewer-Tokens.pdf', 'file_path': 'data\\PDF\\Price-Per-Token-Guide-To-Using-Fewer-Tokens.pdf', 'total_pages': 7, 'format': 'PDF 1.7', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 2}
# page_content='The key is prompt structure. The cached portion must be identical character-for-
# character from the start of the prompt. That means:
# Put stable content first: system prompt, few-shot examples, reference docs
# Put variable content last: the user's actual message, dynamic context
# Don't inject timestamps, request IDs, or session metadata into your system prompt —
# anything dynamic in the prefix invalidates the cache. If you must put dynamic
# information into the system prompt, put it at the end of it.
# What this looks like in practice:
# Say your system prompt is 2,000 tokens and you make 100 calls per day.
# Without caching: 200,000 input tokens/day at full price.
# With caching: 2,000 tokens at full price (first call) + 198,000 tokens at 90% off. That's a
# massive reduction for zero code changes — just making sure your prompt structure is
# cache-friendly.
# To maximize cache hits: - Batch related requests within 5-minute windows so they all hit
# the cache - Don't update system prompt files mid-session — changes invalidate the cache
# - Keep reference docs in the prompt prefix (stable) and user queries at the end (variable)
# Tip 5: Summarize Instead of Stuffing
# One of the most common token sinks is cramming too much raw content into context. Full
# conversation histories, entire retrieved documents, verbose outputs from previous pipeline
# steps — all of it costs tokens, and most of it is noise.
# Conversation history:
# Don't pass your entire chat transcript with every message. Keep the last 3-5 messages
# verbatim (the model needs recent context) and summarize everything before that. A 200-
# token summary of what was discussed earlier replaces 5,000+ tokens of raw message
# history.
# This is especially important for chatbots and agents that run long sessions. Without
# summarization, context grows linearly with every exchange, and you're paying full input
# token price on the entire history every single turn.
# RAG and document retrieval:
# •
# •
# •' metadata={'producer': 'WeasyPrint 68.1', 'creator': '', 'creationdate': '', 'source': 'data\\PDF\\Price-Per-Token-Guide-To-Using-Fewer-Tokens.pdf', 'file_path': 'data\\PDF\\Price-Per-Token-Guide-To-Using-Fewer-Tokens.pdf', 'total_pages': 7, 'format': 'PDF 1.7', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 3}
# page_content='When retrieving documents to answer a question, less is more:
# Retrieve 3 highly relevant chunks, not 10 "maybe relevant" ones
# Use smaller chunk sizes — a 200-token chunk wastes less space than a 1,000-token
# chunk when only one sentence in it is actually relevant
# Pre-filter results before sending them to the LLM. Your vector search's relevance
# scores can eliminate weak matches before they eat context tokens
# Multi-step pipelines:
# If you're chaining multiple LLM calls, don't pass the full raw output of step 1 into step 2.
# Extract only what the next step needs and pass a structured summary. A 50-token JSON
# object is cheaper than a 500-token paragraph that says the same thing.
# Tip 6: Pick the Right Model for the Job
# Many people jump straight to the popular closed-source models like Claude and GPT.
# However, open-source models are catching up in terms of performance and have much
# lower token costs. I personally have been leaning heavily on Kimi K2.5 and recommend
# you try it as well, it a fraction of the cost as using Claude Sonnet with similar results from
# my experience.
# Tip 7: Limit Tool Calls (Especially with RAG)
# If you give an LLM access to search or retrieval tools without limits, it will use them far
# more than necessary. This is one of the biggest hidden token costs in agentic systems.
# The loop looks like this: The model searches for something. Gets results back. Decides
# it needs more information. Searches again. Gets more results. Decides it should check
# one more thing. Searches again. By the time it finally answers, it's burned through 5+
# retrieval calls when 1-2 would have been enough.
# Each round-trip costs you four times over: 1. The model's reasoning tokens (deciding
# what to search) 2. The function call tokens (the search query itself) 3. The returned results
# tokens (the content that comes back) 4. The model's interpretation tokens (reading and
# processing the results)
# •
# •
# •' metadata={'producer': 'WeasyPrint 68.1', 'creator': '', 'creationdate': '', 'source': 'data\\PDF\\Price-Per-Token-Guide-To-Using-Fewer-Tokens.pdf', 'file_path': 'data\\PDF\\Price-Per-Token-Guide-To-Using-Fewer-Tokens.pdf', 'total_pages': 7, 'format': 'PDF 1.7', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 4}
# page_content='Five unnecessary retrieval calls can easily burn 10,000+ tokens. And it compounds —
# each set of results gets added to context, so every subsequent call is more expensive than
# the last. A search loop that starts with 2,000 context tokens can end at 15,000.
# How to prevent this:
# Set a hard cap. Tell the model in the system prompt: "You have a maximum of 3 search
# calls. Use them wisely and answer with what you have." Most models respect this when
# the instruction is clear. You can send warnings to the model as it uses tools that it is
# running out of calls and to wrap up its searching.
# Pre-filter your retrieval. If your vector search returns 20 chunks, trim to the top 3 before
# passing them to the LLM. Don't make the model pay tokens to read content that wasn't
# relevant enough to rank highly.
# Set token limits on tool results. If a retrieved document is 5,000 tokens long, truncate it.
# The model rarely needs the entire document — usually a few hundred tokens contain the
# relevant answer.
# I've tested RAG pipelines with unlimited tool calls and was shocked when one of these
# times I had spent $15 on a single run. I set search call limits to 12 and since then can run
# the pipeline for less than a dollar with similar results as unlimited search.
# Tip 8: Batch Your Requests
# Every API call carries overhead. Your system prompt, any few-shot examples, and the
# conversation setup all get sent every time. If you're making the same type of call
# repeatedly, batching multiple items into a single request means you pay that overhead
# once instead of ten times.
# Instead of this (10 API calls):
# Call 1: "Classify this email: [email 1]"
# Call 2: "Classify this email: [email 2]"
# ...
# Call 10: "Classify this email: [email 10]"
# Do this (1 API call):
# "Classify each of the following emails:
# 1. [email 1]
# 2. [email 2]
# ...' metadata={'producer': 'WeasyPrint 68.1', 'creator': '', 'creationdate': '', 'source': 'data\\PDF\\Price-Per-Token-Guide-To-Using-Fewer-Tokens.pdf', 'file_path': 'data\\PDF\\Price-Per-Token-Guide-To-Using-Fewer-Tokens.pdf', 'total_pages': 7, 'format': 'PDF 1.7', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 5}
# page_content='10. [email 10]
# Return a JSON array with the classification for each."
# Your system prompt tokens get sent once instead of ten times. That alone saves
# thousands of tokens at scale.
# Batch APIs take this further. OpenAI's Batch API offers a 50% discount for requests that
# don't need real-time responses. If you're processing data overnight, running evaluations,
# or doing any kind of bulk work, batch endpoints are significantly cheaper.
# When batching makes sense: - Processing lists of items (emails, support tickets,
# documents) - Non-real-time workloads (nightly data processing, weekly reports) -
# Evaluation and testing (running your prompt against many test cases) - Any repetitive task
# where latency isn't critical
# When it doesn't: Real-time user-facing responses where each message is unique and
# needs immediate replies.
# Compare model pricing and research LLMs at pricepertoken.com.' metadata={'producer': 'WeasyPrint 68.1', 'creator': '', 'creationdate': '', 'source': 'data\\PDF\\Price-Per-Token-Guide-To-Using-Fewer-Tokens.pdf', 'file_path': 'data\\PDF\\Price-Per-Token-Guide-To-Using-Fewer-Tokens.pdf', 'total_pages': 7, 'format': 'PDF 1.7', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 6}
# page_content='' metadata={'producer': 'jsPDF 3.0.0', 'creator': '', 'creationdate': '2026-05-31T15:23:45+05:30', 'source': 'data\\PDF\\screencapture-console-cloud-google-auth-clients-create-2026-05-31-15_23_39.pdf', 'file_path': 'data\\PDF\\screencapture-console-cloud-google-auth-clients-create-2026-05-31-15_23_39.pdf', 'total_pages': 1, 'format': 'PDF 1.3', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': "D:20260531152345+05'30'", 'page': 0}
# page_content='' metadata={'producer': 'jsPDF 3.0.0', 'creator': '', 'creationdate': '2026-05-30T21:54:09+05:30', 'source': 'data\\PDF\\screencapture-resume-now-build-resume-final-resume-2026-05-30-21_54_05.pdf', 'file_path': 'data\\PDF\\screencapture-resume-now-build-resume-final-resume-2026-05-30-21_54_05.pdf', 'total_pages': 1, 'format': 'PDF 1.3', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': "D:20260530215409+05'30'", 'page': 0}

# %%
docs
# Out:
# [Document(metadata={'producer': 'WeasyPrint 68.1', 'creator': '', 'creationdate': '', 'source': 'data\\PDF\\Price-Per-Token-Guide-To-Using-Fewer-Tokens.pdf', 'file_path': 'data\\PDF\\Price-Per-Token-Guide-To-Using-Fewer-Tokens.pdf', 'total_pages': 7, 'format': 'PDF 1.7', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 0}, page_content='Price Per Token Guide to Using Fewer\nTokens\nMost developers use 2-5x more tokens than they need to. Here\'s how to fix that.\nThis guide covers eight practical ways to cut your token usage. Each one is independent\n— you can start with whichever applies to you — but they compound when used together.\nTip 1: Trim Your System Prompt\nYour system prompt gets sent with every single API call. There\'s no getting around that if\nyou\'re using an LLM as an assistant because each call is stateless- all the context needs\nto be included in every input. It is worth spending time on a frequently used system prompt\nfor this reason\nMost system prompts are far longer than they need to be. Common sources of bloat:\n"You are a helpful assistant that..." — The model already knows this. Cut it.\nRedundant formatting instructions — Telling the model three different ways to use\nbullet points doesn\'t help more than telling it once.\nPoliteness and motivation — "Please always try your best to provide accurate..." is\nfiller. LLMs don\'t try harder because you said please.\nReference material — If you\'re pasting documentation into the system prompt, move it\nto retrieval (RAG) or tool calls instead. It doesn\'t belong in every request.\nThe rule of thumb: Remove a line from your system prompt. If the model\'s behavior\ndoesn\'t change, leave it out.\nExample:\nBefore (roughly 800 tokens):\nYou are a helpful, knowledgeable AI assistant specializing in customer support\nfor our e-commerce platform. You should always be polite, professional, and\nthorough in your responses. When a customer asks about an order, you should\nlook up their order details and provide a comprehensive summary including the\norder date, items ordered, shipping status, estimated delivery date, and any\nrelevant tracking information. You should always ask if there\'s anything else\nyou can help with at the end of your response. If you don\'t know the answer,\n• \n• \n• \n•'),
#  Document(metadata={'producer': 'WeasyPrint 68.1', 'creator': '', 'creationdate': '', 'source': 'data\\PDF\\Price-Per-Token-Guide-To-Using-Fewer-Tokens.pdf', 'file_path': 'data\\PDF\\Price-Per-Token-Guide-To-Using-Fewer-Tokens.pdf', 'total_pages': 7, 'format': 'PDF 1.7', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 1}, page_content='say so honestly rather than making something up. Format your responses clearly\nwith bullet points where appropriate...\nAfter (roughly 200 tokens):\nCustomer support agent for [Company]. Look up order details when asked.\nBe concise. If unsure, say so. Use the order_lookup tool for order queries.\nSame behavior. 600 fewer tokens per call. At 200 calls/day, that\'s 120,000 tokens saved\ndaily — purely from deleting words the model didn\'t need. Details about looking up order\ndates, items ordered, etc can be included in tool definitions and picked up into context only\nwhen necessary.\nTip 2: Control Your Output Length\nIf you don\'t tell the model how long to respond, it will use as many tokens as it wants. This\nmatters because output tokens are the expensive ones — typically 3-5x the cost of input\ntokens.\nA few ways to control this:\nSet max_tokens  explicitly. Most people leave this at the default, which is often the\nmodel\'s maximum context window. If you only need a one-paragraph answer, don\'t leave\nroom for an essay.\nBe specific in your instructions: - "Respond in 2-3 sentences" works better than "be\nbrief" - "Keep your answer under 100 words" gives a hard target - "Return only the\ncategory name, nothing else" eliminates all filler\nAsk for bullets instead of prose. The same information in bullet point format uses fewer\ntokens than full paragraphs. If you\'re going to extract the key points anyway, have the\nmodel do it upfront.\nFor classification and routing tasks, constrain the output to a single word or a short\nJSON value. There\'s no reason a sentiment classifier should return "The sentiment of this\ntext is positive because the author expresses satisfaction with..." when it could return \n"positive" .\nThe math: If a typical response is 2,000 tokens and you can bring it down to 500, you\'re\nsaving 75% on the most expensive part of every call. Check what output tokens cost for\nyour model at pricepertoken.com — the difference between controlled and uncontrolled\noutput adds up fast.'),
#  Document(metadata={'producer': 'WeasyPrint 68.1', 'creator': '', 'creationdate': '', 'source': 'data\\PDF\\Price-Per-Token-Guide-To-Using-Fewer-Tokens.pdf', 'file_path': 'data\\PDF\\Price-Per-Token-Guide-To-Using-Fewer-Tokens.pdf', 'total_pages': 7, 'format': 'PDF 1.7', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 2}, page_content='Tip 3: Use Structured Outputs\nWhen you need data back from a model — not conversation, not creative writing, just data\n— structured outputs are the most token-efficient way to get it.\nJSON mode and structured output schemas (available in OpenAI and Anthropic APIs)\nconstrain the model\'s response to match a predefined format. That means:\nNo "Sure! Here\'s what I found:" preamble\nNo trailing "Let me know if you need anything else!"\nNo inconsistent formatting between calls\nJust the fields you asked for, in the shape you defined\nStructured responses are typically 30-60% shorter than free-form text containing the same\ninformation. And they\'re easier to parse — no regex, no "sometimes it includes a header\nand sometimes it doesn\'t."\nWhen to use structured outputs: - Data extraction (pull name, date, amount from text) -\nClassification (return a category label, not an explanation of why) - Multi-step pipelines\n(pass clean data between steps) - Any time you\'re going to parse the response\nprogrammatically\nPydantic AI is worth looking at if you\'re working in Python. It lets you define your output\nschema as a Pydantic model, and the LLM is forced to return data matching that schema.\nNo parsing code, no surprises, no wasted tokens on filler text. It works across multiple\nproviders including OpenAI and Anthropic.\nI personally strictly Pydantic AI for almost all use cases (I am not affiliated). It allows you to\ndefine each part of an output which in turn gives you predictable output formats at a\ncontrolled length.\nTip 4: Cache What Doesn\'t Change\nPrompt caching gives you a 90% discount on tokens the API has already processed. If\nyour prompts have a stable prefix — and most do — this is essentially free savings.\nHow it works: The first time you send a prompt, you pay full price. On subsequent\nrequests within the cache window (5 minutes for Anthropic, similar for OpenAI), any tokens\nthat match the cached prefix cost 90% less.\n• \n• \n• \n•'),
#  Document(metadata={'producer': 'WeasyPrint 68.1', 'creator': '', 'creationdate': '', 'source': 'data\\PDF\\Price-Per-Token-Guide-To-Using-Fewer-Tokens.pdf', 'file_path': 'data\\PDF\\Price-Per-Token-Guide-To-Using-Fewer-Tokens.pdf', 'total_pages': 7, 'format': 'PDF 1.7', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 3}, page_content="The key is prompt structure. The cached portion must be identical character-for-\ncharacter from the start of the prompt. That means:\nPut stable content first: system prompt, few-shot examples, reference docs\nPut variable content last: the user's actual message, dynamic context\nDon't inject timestamps, request IDs, or session metadata into your system prompt —\nanything dynamic in the prefix invalidates the cache. If you must put dynamic\ninformation into the system prompt, put it at the end of it.\nWhat this looks like in practice:\nSay your system prompt is 2,000 tokens and you make 100 calls per day.\nWithout caching: 200,000 input tokens/day at full price.\nWith caching: 2,000 tokens at full price (first call) + 198,000 tokens at 90% off. That's a\nmassive reduction for zero code changes — just making sure your prompt structure is\ncache-friendly.\nTo maximize cache hits: - Batch related requests within 5-minute windows so they all hit\nthe cache - Don't update system prompt files mid-session — changes invalidate the cache\n- Keep reference docs in the prompt prefix (stable) and user queries at the end (variable)\nTip 5: Summarize Instead of Stuffing\nOne of the most common token sinks is cramming too much raw content into context. Full\nconversation histories, entire retrieved documents, verbose outputs from previous pipeline\nsteps — all of it costs tokens, and most of it is noise.\nConversation history:\nDon't pass your entire chat transcript with every message. Keep the last 3-5 messages\nverbatim (the model needs recent context) and summarize everything before that. A 200-\ntoken summary of what was discussed earlier replaces 5,000+ tokens of raw message\nhistory.\nThis is especially important for chatbots and agents that run long sessions. Without\nsummarization, context grows linearly with every exchange, and you're paying full input\ntoken price on the entire history every single turn.\nRAG and document retrieval:\n• \n• \n•"),
#  Document(metadata={'producer': 'WeasyPrint 68.1', 'creator': '', 'creationdate': '', 'source': 'data\\PDF\\Price-Per-Token-Guide-To-Using-Fewer-Tokens.pdf', 'file_path': 'data\\PDF\\Price-Per-Token-Guide-To-Using-Fewer-Tokens.pdf', 'total_pages': 7, 'format': 'PDF 1.7', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 4}, page_content='When retrieving documents to answer a question, less is more:\nRetrieve 3 highly relevant chunks, not 10 "maybe relevant" ones\nUse smaller chunk sizes — a 200-token chunk wastes less space than a 1,000-token\nchunk when only one sentence in it is actually relevant\nPre-filter results before sending them to the LLM. Your vector search\'s relevance\nscores can eliminate weak matches before they eat context tokens\nMulti-step pipelines:\nIf you\'re chaining multiple LLM calls, don\'t pass the full raw output of step 1 into step 2.\nExtract only what the next step needs and pass a structured summary. A 50-token JSON\nobject is cheaper than a 500-token paragraph that says the same thing.\nTip 6: Pick the Right Model for the Job\nMany people jump straight to the popular closed-source models like Claude and GPT.\nHowever, open-source models are catching up in terms of performance and have much\nlower token costs. I personally have been leaning heavily on Kimi K2.5 and recommend\nyou try it as well, it a fraction of the cost as using Claude Sonnet with similar results from\nmy experience.\nTip 7: Limit Tool Calls (Especially with RAG)\nIf you give an LLM access to search or retrieval tools without limits, it will use them far\nmore than necessary. This is one of the biggest hidden token costs in agentic systems.\nThe loop looks like this: The model searches for something. Gets results back. Decides\nit needs more information. Searches again. Gets more results. Decides it should check\none more thing. Searches again. By the time it finally answers, it\'s burned through 5+\nretrieval calls when 1-2 would have been enough.\nEach round-trip costs you four times over: 1. The model\'s reasoning tokens (deciding\nwhat to search) 2. The function call tokens (the search query itself) 3. The returned results\ntokens (the content that comes back) 4. The model\'s interpretation tokens (reading and\nprocessing the results)\n• \n• \n•'),
#  Document(metadata={'producer': 'WeasyPrint 68.1', 'creator': '', 'creationdate': '', 'source': 'data\\PDF\\Price-Per-Token-Guide-To-Using-Fewer-Tokens.pdf', 'file_path': 'data\\PDF\\Price-Per-Token-Guide-To-Using-Fewer-Tokens.pdf', 'total_pages': 7, 'format': 'PDF 1.7', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 5}, page_content='Five unnecessary retrieval calls can easily burn 10,000+ tokens. And it compounds —\neach set of results gets added to context, so every subsequent call is more expensive than\nthe last. A search loop that starts with 2,000 context tokens can end at 15,000.\nHow to prevent this:\nSet a hard cap. Tell the model in the system prompt: "You have a maximum of 3 search\ncalls. Use them wisely and answer with what you have." Most models respect this when\nthe instruction is clear. You can send warnings to the model as it uses tools that it is\nrunning out of calls and to wrap up its searching.\nPre-filter your retrieval. If your vector search returns 20 chunks, trim to the top 3 before\npassing them to the LLM. Don\'t make the model pay tokens to read content that wasn\'t\nrelevant enough to rank highly.\nSet token limits on tool results. If a retrieved document is 5,000 tokens long, truncate it.\nThe model rarely needs the entire document — usually a few hundred tokens contain the\nrelevant answer.\nI\'ve tested RAG pipelines with unlimited tool calls and was shocked when one of these\ntimes I had spent $15 on a single run. I set search call limits to 12 and since then can run\nthe pipeline for less than a dollar with similar results as unlimited search.\nTip 8: Batch Your Requests\nEvery API call carries overhead. Your system prompt, any few-shot examples, and the\nconversation setup all get sent every time. If you\'re making the same type of call\nrepeatedly, batching multiple items into a single request means you pay that overhead\nonce instead of ten times.\nInstead of this (10 API calls):\nCall 1: "Classify this email: [email 1]"\nCall 2: "Classify this email: [email 2]"\n...\nCall 10: "Classify this email: [email 10]"\nDo this (1 API call):\n"Classify each of the following emails:\n1. [email 1]\n2. [email 2]\n...'),
#  Document(metadata={'producer': 'WeasyPrint 68.1', 'creator': '', 'creationdate': '', 'source': 'data\\PDF\\Price-Per-Token-Guide-To-Using-Fewer-Tokens.pdf', 'file_path': 'data\\PDF\\Price-Per-Token-Guide-To-Using-Fewer-Tokens.pdf', 'total_pages': 7, 'format': 'PDF 1.7', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 6}, page_content='10. [email 10]\nReturn a JSON array with the classification for each."\nYour system prompt tokens get sent once instead of ten times. That alone saves\nthousands of tokens at scale.\nBatch APIs take this further. OpenAI\'s Batch API offers a 50% discount for requests that\ndon\'t need real-time responses. If you\'re processing data overnight, running evaluations,\nor doing any kind of bulk work, batch endpoints are significantly cheaper.\nWhen batching makes sense: - Processing lists of items (emails, support tickets,\ndocuments) - Non-real-time workloads (nightly data processing, weekly reports) -\nEvaluation and testing (running your prompt against many test cases) - Any repetitive task\nwhere latency isn\'t critical\nWhen it doesn\'t: Real-time user-facing responses where each message is unique and\nneeds immediate replies.\nCompare model pricing and research LLMs at pricepertoken.com.'),
#  Document(metadata={'producer': 'jsPDF 3.0.0', 'creator': '', 'creationdate': '2026-05-31T15:23:45+05:30', 'source': 'data\\PDF\\screencapture-console-cloud-google-auth-clients-create-2026-05-31-15_23_39.pdf', 'file_path': 'data\\PDF\\screencapture-console-cloud-google-auth-clients-create-2026-05-31-15_23_39.pdf', 'total_pages': 1, 'format': 'PDF 1.3', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': "D:20260531152345+05'30'", 'page': 0}, page_content=''),
#  Document(metadata={'producer': 'jsPDF 3.0.0', 'creator': '', 'creationdate': '2026-05-30T21:54:09+05:30', 'source': 'data\\PDF\\screencapture-resume-now-build-resume-final-resume-2026-05-30-21_54_05.pdf', 'file_path': 'data\\PDF\\screencapture-resume-now-build-resume-final-resume-2026-05-30-21_54_05.pdf', 'total_pages': 1, 'format': 'PDF 1.3', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': "D:20260530215409+05'30'", 'page': 0}, page_content='')]
