# %%
from deepagents import create_deep_agent
from langchain.chat_models import init_chat_model
from dotenv import load_dotenv 
load_dotenv()
from tavily import TavilyClient
from typing import Literal
import json
import os

# %%
tavily_client=TavilyClient(os.getenv("TAVILY_API_KEY"))
os.environ['GROQ_API_KEY']=os.getenv("GROQ_API_KEY")

# %%
def web_search(query: str):
    """Search the web and return concise results."""

    result = tavily_client.search(
        query=query,
        max_results=3,
        include_raw_content=False,
        topic="news"
    )

    items = []

    for r in result["results"]:
        items.append(
            {
                "title": r["title"],
                "content": r["content"][:200],
                "url": r["url"]
            }
        )

    return json.dumps(items)

# %%
agent = create_deep_agent(
    model="groq:openai/gpt-oss-120b",
    tools=[web_search],
    system_prompt="You are a helpful assistant",
)

# %%
result = agent.invoke({
    "messages": [
        {
            "role": "user",
            "content": "current IPL news"
        }
    ]
})
result['messages'][-1].content
# Out:
# '**Latest IPL (Indian Premier League) news (as of early June\u202f2026)**  \n\n- **Royal Challengers Bengaluru (RCB) win the 2026 title** – RCB defeated Gujarat Titans in the final to claim the championship. Virat\u202fKohli played a match‑winning unbeaten 75, sealing the victory.  \n- **Vaibhav Sooryavanshi’s breakout season** – The young all‑rounder earned multiple IPL awards, including the Emerging Player award, after his stellar performances throughout the tournament.  \n- **Gujarat Titans finish as runners‑up** – Despite a strong campaign and a solid bowling unit, the Titans fell short in the final but secured the “Runners‑Up” award.  \n- **Dinesh Karthik’s behind‑the‑scenes role** – Former India keeper turned commentator and analyst, Dinesh\u202fKarthik, has been highlighted in a new IPL‑T20 video series discussing strategy and player development.  \n- **Emerging talent spotlight** – Rajat\u202fPatidar (Rajasthan Royals) and other young prospects are being touted as potential three‑peat candidates for future seasons.  \n\n*These items capture the most recent headlines and notable storylines from the ongoing IPL 2026 season.*'
